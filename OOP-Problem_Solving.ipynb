# %%
class Customer:
    def __init__(self,name):
        self.name=name
    def greet(self,nem=None):
        if nem:
            print(f"Hello! {nem}")
        else:
            print("Hello!")
    def purchase(self,*items):
        print(self.name,"you purchase",len(items),"iteam(s):")
        for i in items:
            print(i)
            
customer_1 = Customer("Sam")
customer_1.greet()
customer_1.purchase("chips", "chocolate", "orange juice")
print("-----------------------------")
customer_2 = Customer("David")
customer_2.greet("David")
customer_2.purchase("orange juice")
# Out:
# Hello!
# Sam you purchase 3 iteam(s):
# chips
# chocolate
# orange juice
# -----------------------------
# Hello! David
# David you purchase 1 iteam(s):
# orange juice

# %%
class Panda:
    def __init__(self,name,gender,age):
        self.name=name
        self.gender=gender
        self.age=age
    def sleep(self,hour=0):
        if 3<=hour<=5:
            return f"{self.name} have {hour} daily and should have Mixed Veggies"
        elif 6<=hour<=8:
            return f"{self.name} have {hour} daily and should have Eggplant & Tofu"
        elif 9<=hour<=11:
            return f"{self.name} have {hour} daily and should have Broccoli Chicken"
        else:
            return f"{self.name} should have bamboo leaves"
            

panda1 = Panda("Kunfu", "Male", 5)
panda2 = Panda("Pan Pan", "Female",3)
panda3 = Panda("Ming Ming", "Female",8)

print("{} is a {} Panda Bear who is {} years old".format(panda1.name,panda1.gender,panda1.age))

print("{} is a {} Panda Bear who is {} years old".format(panda2.name,panda2.gender,panda2.age))

print("{} is a {} Panda Bear who is {} years old".format(panda3.name,panda3.gender,panda3.age))
print("===========================")
print(panda2.sleep(10))
print(panda1.sleep(4))
print(panda3.sleep())
# Out:
# Kunfu is a Male Panda Bear who is 5 years old
# Pan Pan is a Female Panda Bear who is 3 years old
# Ming Ming is a Female Panda Bear who is 8 years old
# ...
# Pan Pan have 10 daily and should have Broccoli Chicken
# Kunfu have 4 daily and should have Mixed Veggies
# Ming Ming should have bamboo leaves

# %%
class Cat:
    def __init__(self,colour="White",action="sittin"):
        self.colour=colour
        self.action=action
    def printCat(self):
        print(f"{self.colour} cat is {self.action}")
    def changeColor(self,changeColour):
        self.colour=changeColour

c1 = Cat()
c2 = Cat("Black")
c3 = Cat("Brown", "jumping")
c4 = Cat("Red", "purring")
c1.printCat()
c2.printCat()
c3.printCat()
c4.printCat()
c1.changeColor("Blue")
c3.changeColor("Purple")
c1.printCat()
c3.printCat()
# Out:
# White cat is sittin
# Black cat is sittin
# Brown cat is jumping
# Red cat is purring
# Blue cat is sittin
# Purple cat is jumping

# %%
class Student:
    def __init__(self,name="defult student"):
        self.name=name
        self.final=0
    def quizcalc(self,score1=0,score2=0,score3=0):
        self.final=(score1+score2+score3)/3
    def printdetail(self):
        print(f"your average quiz score {self.final}")


s1 = Student()
s1.quizcalc(10)
print('--------------------------------')
s1.printdetail()
s2 = Student('Harry')
s2.quizcalc(10,8)
print('--------------------------------')
s2.printdetail()
s3 = Student('Hermione')
s3.quizcalc(10,9,10)
print('--------------------------------')
s3.printdetail()
# Out:
# --------------------------------
# your average quiz score 3.3333333333333335
# --------------------------------
# your average quiz score 6.0
# --------------------------------
# your average quiz score 9.666666666666666

# %%
class Student:
    def __init__(self,name="",ID=0,dep="CSE"):
        self.name=name
        self.ID=ID
        self.dep=dep
        self.hour=0
    def dailyEffort(self,hour):
        self.hour=hour
    def printDetails(self):
        print(f"Name:{self.name}")
        print(f"ID:{self.ID}")
        print(f"Depertment:{self.dep}")
        print(f"Daily effort:{self.hour}")
        if self.hour<=2:
            print(f"Suggestion:Should give more effort")
        elif self.hour<=4:
            print(f"Suggestion:Keep up the good work")
        else:
            print(f"Suggestion:Excillent! Now motivate others")

harry = Student('Harry Potter', 123)
harry.dailyEffort(3)
harry.printDetails()	
print('========================')
john = Student("John Wick", 456, "BBA")
john.dailyEffort(2)
john.printDetails()
print('========================')
naruto = Student("Naruto Uzumaki", 777, "Ninja")
naruto.dailyEffort(6)
naruto.printDetails()
# Out:
# Name:Harry Potter
# ID:123
# Depertment:CSE
# Daily effort:3
# Suggestion:Keep up the good work
# ...
# Name:John Wick
# ID:456
# Depertment:BBA
# Daily effort:2
# Suggestion:Should give more effort
# ...
# Name:Naruto Uzumaki
# ID:777
# Depertment:Ninja
# Daily effort:6
# Suggestion:Excillent! Now motivate others

# %%
class Patient:
    def __init__(self,name,age):
        self.name=name
        self.age=age
        self.symptom=[]
    def add_Symptom(self,*symptom):
        for s in symptom:
            self.symptom.append(s)
    def printPatientDetail(self):
        print(f"Name:{self.name}")
        print(f"Age:{self.age}")
        print("Symptoms:",end="")
        count=1
        for i in self.symptom:
            if count==len(self.symptom):
                print(i,end="")
            else:
                print(i,end=",")
            count+=1
        print()


p1 = Patient("Thomas", 23)
p1.add_Symptom("Headache")
p2 = Patient("Carol", 20)
p2.add_Symptom("Vomiting", "Coughing")
p3 = Patient("Mike", 25)
p3.add_Symptom("Fever", "Headache", "Coughing")
print("=========================")
p1.printPatientDetail()
print("=========================")
p2.printPatientDetail()
print("=========================")
p3.printPatientDetail()
# Out:
# ...
# Name:Thomas
# Age:23
# Symptoms:Headache
# ...
# Name:Carol
# Age:20
# Symptoms:Vomiting,Coughing
# ...
# Name:Mike
# Age:25
# Symptoms:Fever,Headache,Coughing

# %%
##7
class Match:
    def __init__(self,teams):
        teamArgs = teams.split("-")
        self.batting=teamArgs[0]
        self.bowling=teamArgs[1]
        self.wicket=0
        self.over=0
        self.run = 0
        print(f"5..4..3..2..1.. Play !!!")
    def add_run(self,add):
        self.run+=add
    def add_over(self,over):
        if self.over+over>5:
            print(f"Warning! Cannot add {over} over/s (5 over match)")
        else:
            self.over+=over
    def add_wicket(self,wicket):
        self.wicket+=wicket
    def print_scoreboard(self):
        return f"Batting Team:{self.batting}\nBowling team:{self.bowling}\nTotal run:{self.run} Wicket:{self.wicket} Overs:{self.over}"


match1 = Match("Rangpur Riders-Cumilla Victorians")
print("=========================")
match1.add_run(4)
match1.add_run(6)
match1.add_over(1)
print(match1.print_scoreboard())
print("=========================")
match1.add_over(5)
print("=========================")
match1.add_wicket(1)
print(match1.print_scoreboard())
# Out:
# 5..4..3..2..1.. Play !!!
# ...
# Batting Team:Rangpur Riders
# Bowling	 team:Cumilla Victorians
# Total run:10 Wicket:0 Overs:1
# ...
# Warning! Cannot add 5 over/s (5 over match)
# ...
# Batting Team:Rangpur Riders
# Bowling	 team:Cumilla Victorians
# Total run:10 Wicket:1 Overs:1

# %%
##8
class ParcelKoro:
    def __init__(self,name="No name set",weight=0):
        self.product_name=name
        self.product_weight=weight
        self.fee=0
    def product_weight(self,weight=0):
        self.product_weight=weight
    def calculateFee(self,fee=""):
        if self.product_weight==0:
            self.fee==0
        else:
            if len(fee)>1:
                self.fee+=(self.product_weight*20)+100
            else:
                self.fee+=(self.product_weight*20)+50
    def printDetails(self):
        print(f"Customer Name:{self.product_name}")
        print(f"Product Weight:{self.product_weight}")
        print(f"Total fee:{self.fee}")



print("**********************")
p1 = ParcelKoro()
p1.calculateFee()
p1.printDetails()
print("**********************")
p2 = ParcelKoro('Bob The Builder')
p2.calculateFee()
p2.printDetails()
print("----------------------------")
p2.product_weight=15
p2.calculateFee()
p2.printDetails()
print("**********************")
p3 = ParcelKoro('Dora The Explorer', 10)
p3.calculateFee('Dhanmondi')
p3.printDetails()
# Out:
# **********************
# Customer Name:No name set
# Product Weight:0
# Total fee:0
# **********************
# Customer Name:Bob The Builder
# Product Weight:0
# Total fee:0
# ----------------------------
# Customer Name:Bob The Builder
# Product Weight:15
# Total fee:350
# **********************
# Customer Name:Dora The Explorer
# Product Weight:10
# Total fee:300

# %%
##9
class Batsman:
    def __init__(self, *args):
        if len(args) == 2:
            self.name="New Batsman"
            self.run=args[0]
            self.ball=args[1]
            self.rate=0
        elif len(args) == 3:
            self.name=args[0]
            self.run=args[1]
            self.ball=args[2]
            self.rate=0
    def battingStrikeRate(self):
        self.rate+=(self.run/self.ball)*100
        return self.rate
    def setName(self,new_name):
        self.name=new_name
    def printCareerStatistics(self):
        print(f"Name:{self.name}")
        print(f"Run Score:{self.run}, Ball Faced:{self.ball}")

b1 = Batsman(6101, 7380)
b1.printCareerStatistics()
print("============================")
b2 = Batsman("Liton Das", 678, 773)
b2.printCareerStatistics()
print("----------------------------")
print(b2.battingStrikeRate())
print("============================")
b1.setName("Shakib Al Hasan")
b1.printCareerStatistics()
print("----------------------------")
print(b1.battingStrikeRate())
# Out:
# Name:New Batsman
# Run Score:6101, Ball Faced:7380
# ...
# Name:Liton Das
# Run Score:678, Ball Faced:773
# ----------------------------
# 87.71021992238033
# ...
# Name:Shakib Al Hasan
# Run Score:6101, Ball Faced:7380
# ----------------------------
# 82.66937669376694

# %%
class EPL_Team:
    def __init__(self,team,song="No Slogan"):
        self.team=team
        self.song=song
        self.title=0
    def increaseTitle(self,inc=1):
        self.title+=inc
    def changeSong(self,new_song):
        self.song=new_song
    def showClubInfo(self):
        return f"Name:{self.team} Song:{self.song} Title:{self.title}"

manu = EPL_Team('Manchester United', 'Glory Glory Man United')
chelsea = EPL_Team('Chelsea')
print('===================')
print(manu.showClubInfo())
print('##################')
manu.increaseTitle()
print(manu.showClubInfo())
print('===================')
print(chelsea.showClubInfo())
chelsea.changeSong('Keep the blue flag flying high')
print(chelsea.showClubInfo())
# Out:
# ...
# Name:Manchester United Song:Glory Glory Man United Title:0
# ##################
# Name:Manchester United Song:Glory Glory Man United Title:1
# ...
# Name:Chelsea Song:No Slogan Title:0
# Name:Chelsea Song:Keep the blue flag flying high Title:0

# %%
class Author:
    def __init__(self,name="",*books):
        self.name=name
        self.bookList=[]
        for b in books:
            self.bookList.append(b)
    def addBooks(self,*addbooks):
        for a in addbooks:
            self.bookList.append(a)
    def changeName(self,newName):
        self.name=newName
    def printDetails(self):
        print(f"Name:{self.name}")
        print("--------")
        print("List of Books:")
        for bok in self.bookList:
            print(bok)

auth1 = Author('Humayun Ahmed')
auth1.addBooks('Deyal', 'Megher Opor Bari')
auth1.printDetails()
print("===================")
auth2 = Author()
print(auth2.name)
auth2.changeName('Mario Puzo')
auth2.addBooks('The Godfather', 'Omerta', 'The Sicilian')
print("===================")
auth2.printDetails()
print("===================")
auth3 = Author('Paolo Coelho', 'The Alchemist', 'The Fifth Mountain')
auth3.printDetails()
# Out:
# Name:Humayun Ahmed
# --------
# List of Books:
# Deyal
# Megher Opor Bari
# ...
#
# ...
# Name:Mario Puzo
# --------
# List of Books:
# The Godfather
# Omerta
# The Sicilian
# ...
# Name:Paolo Coelho
# --------
# List of Books:
# The Alchemist
# The Fifth Mountain

# %%
class Circle:
    def __init__(self,rad):
        self.__rad=rad
    def getRadius(self):
        return self.__rad
    def setRadius(self,r):
        self.__rad=r
    def area(self):
        return 3.1416*(self.getRadius()**2)

c1 = Circle(4)
print("First circle radius:" , c1.getRadius())
print("First circle area:" , c1.area())


c2 = Circle(5)
print("Second circle radius:" , c2.getRadius())
print("Second circle area:" , c2.area())
# Out:
# First circle radius: 2
# First circle area: 12.5664
# Second circle radius: 5
# Second circle area: 78.53999999999999

# %%
class Triangle:
    def __init__(self,base,height):
        self.__base=base
        self.__height=height
    def setBase(self,new_base):
        self.__base=new_base
    def setHeight(self,new_height):
        self.__height=new_height
    def getBase(self):
        return self.__base
    def getHeight(self):
        return self.__height
    def area(self):
        return (((self.getBase())*(self.getHeight()))/2)
    
    
    
t1 = Triangle(10, 5)
print("First Triangle Base:" , t1.getBase())
print("First Triangle Height:" , t1.getHeight())
print("First Triangle area:" ,t1.area())

t2 = Triangle(5, 3)
print("Second Triangle Base:" , t2.getBase())
print("Second Triangle Height:" , t2.getHeight())
print("Second Triangle area:" ,t2.area())
# Out:
# First Triangle Base: 10
# First Triangle Height: 5
# First Triangle area: 25.0
# Second Triangle Base: 5
# Second Triangle Height: 3
# Second Triangle area: 7.5

# %%
class Teacher:
    def __init__(self,name,dep):
        self.__name=name
        self.__dep=dep
        self.__course=[]
    def addCourse(self,course):
        self.__course.append(course)
    
    def printDetail(self):
        print("====================================")
        print(f"Name:{self.__name}")
        print(f"Depertment:{self.__dep}")
        print("List of course")
        print("====================================")
        for c in self.__course:
            print(c.courseName)
        print("====================================")

class Course:
    def __init__(self,courseName):
        self.courseName=courseName




t1 = Teacher("Saad Abdullah", "CSE")
t2 = Teacher("Mumit Khan", "CSE")
t3 = Teacher("Sadia Kazi", "CSE")                          
c1 = Course("CSE 110 Programming Language I")                           
c2 = Course("CSE 111 Programming Language-II")                           
c3 = Course("CSE 220 Data Structures")                           
c4 = Course("CSE 221 Algorithms")                           
c5 = Course("CSE 230 Discrete Mathematics")                           
c6 = Course("CSE 310 Object Oriented Programming")                           
c7 = Course("CSE 320 Data Communications")                          
c8 = Course("CSE 340 Computer Architecture") 
t1.addCourse(c1)
t1.addCourse(c2)
t2.addCourse(c3)
t2.addCourse(c4)
t2.addCourse(c5)
t3.addCourse(c6)
t3.addCourse(c7)
t3.addCourse(c8)
t1.printDetail()
t2.printDetail()
t3.printDetail()
# Out:
# ...
# Name:Saad Abdullah
# Depertment:CSE
# List of course
# ...
# CSE 110 Programming Language I
# CSE 111 Programming Language-II
# ...
# Name:Mumit Khan
# Depertment:CSE
# List of course
# ...
# CSE 220 Data Structures
# CSE 221 Algorithms
# CSE 230 Discrete Mathematics
# ...
# Name:Sadia Kazi
# Depertment:CSE
# List of course
# ...
# CSE 310 Object Oriented Programming
# CSE 320 Data Communications
# CSE 340 Computer Architecture
# ...

# %%
class Team:
    def __init__(self,name=None):
        if name:
            self.__name=name
        self.__player=[]
    def setName(self,newName):
        self.__name=newName
    def getName(self):
        return self.__name
    def addPlayer(self,addPlayer):
        self.__player.append(addPlayer)
    def printDetail(self):
        print("=====================")
        print(f"Team:{self.__name}")
        print("List of player:")
        s=""
        s+="["
        for p in self.__player:
            s+="'"+p.name+"',"
        s=s[:len(s)-1] + "]"
        print(s)
class Player:
    def __init__(self,player):
        self.name=player
        
        
b = Team()
b.setName('Bangladesh')
mashrafi = Player("Mashrafi")
b.addPlayer(mashrafi)
tamim = Player("Tamim")
b.addPlayer(tamim)
b.printDetail()
a = Team("Australia")
ponting = Player("Ponting")
a.addPlayer(ponting)
lee = Player("Lee")
a.addPlayer(lee)
a.printDetail()
# Out:
# ...
# Team:Bangladesh
# List of player:
# ['Mashrafi','Tamim']
# ...
# Team:Australia
# List of player:
# ['Ponting','Lee']

# %%
class Account: 
    def __init__(self, balance):
        self._balance = balance
        
    def getBalance(self):
        return self._balance
class CheckingAccount(Account):
    numberOfAccount=0
    def __init__(self,amount=0):
        super().__init__(amount)
        CheckingAccount.numberOfAccount+=1
    def __str__(self):
        return f"Acount Balance: {self.getBalance()}"

    
print('Number of Checking Accounts: ', CheckingAccount.numberOfAccount)
print(CheckingAccount())
print(CheckingAccount(100.00))
print(CheckingAccount(200.00))
print('Number of Checking Accounts: ', CheckingAccount.numberOfAccount)
# Out:
# Number of Checking Accounts:  0
# Acount Balance: 0
# Acount Balance: 100.0
# Acount Balance: 200.0
# Number of Checking Accounts:  3

# %%
class Fruit:
    def __init__(self, formalin=False, name=''):
        self.__formalin = formalin
        self.name = name
    
    def getName(self):
        return self.name
    
    def hasFormalin(self):
        return self.__formalin
    
class testFruit:
    def test(self, f):
        print('----Printing Detail----')
        if f.hasFormalin():
            print('Do not eat the',f.getName(),'.')
            print(f)
        else:
            print('Eat the',f.getName(),'.')
            print(f)
            
class Mango(Fruit):
    def __init__(self,name="Mango",f=True):
        super().__init__(f,name)
    def __str__(self):
        return "Mangos are bad for you"
class Jackfruit(Fruit):
    def __init__(self,name="Jackfruit",f=False):
        super().__init__(f,name)
    def __str__(self):
        return "Jackfruits are good for you"
        
m = Mango()
j = Jackfruit()
t1 = testFruit()
t1.test(m)
t1.test(j)
# Out:
# ----Printing Detail----
# Do not eat the Mango .
# Mangos are bad for you
# ----Printing Detail----
# Eat the Jackfruit .
# Jackfruits are good for you

# %%
class Exam:
    def __init__(self,marks):
        self.marks = marks
        self.time = 60
        
    def examSyllabus(self):
        return "Maths , English"
    def examParts(self):
        return "Part 1 - Maths\nPart 2 - English\n"

class ScienceExam(Exam):
    def __init__(self,marks,time,*syllabus):
        self.marks=marks
        self.time1=time
        self.syllabus=[]
        self.syllabus.append("Math")
        self.syllabus.append("English")
        self.parts=2
        for  s in syllabus:
            self.parts+=1
            self.syllabus.append(s)
        super().__init__(marks)
    def __str__(self):
        return f"Marks: {self.marks} Time: {self.time1} minutes Number of parts: {self.parts}"
    def examSyllabus(self):
        return ','.join(self.syllabus)
    def examParts(self):
        r=""
        for i in range (self.parts):
            if i == 0:
                r += "Part "+str(i+1)+" - "+self.syllabus[i]
            else:
                r += "\nPart "+str(i+1)+" - "+self.syllabus[i]
        return r
    
engineering = ScienceExam(100,90,"Physics","HigherMaths")
print(engineering)
print('----------------------------------')
print(engineering.examSyllabus())
print(engineering.examParts())
print('==================================') 
architecture = ScienceExam(100,120,"Physics","HigherMaths","Drawing")
print(architecture)
print('----------------------------------')
print(architecture.examSyllabus())
print(architecture.examParts())
# Out:
# Marks: 100 Time: 90 minutes Number of parts: 4
# ----------------------------------
# Math,English,Physics,HigherMaths
# Part 1 - Math
# Part 2 - English
# Part 3 - Physics
# Part 4 - HigherMaths
# ...
# Marks: 100 Time: 120 minutes Number of parts: 5
# ----------------------------------
# Math,English,Physics,HigherMaths,Drawing
# Part 1 - Math
# Part 2 - English
# Part 3 - Physics
# Part 4 - HigherMaths
# Part 5 - Drawing

# %%
class Shape3D:

    pi = 3.14159
    def __init__(self, name = 'Default', radius = 0):
        self._area = 0
        self._name = name
        self._height = 'No need'
        self._radius = radius   

    def calc_surface_area(self):
        return 2 * Shape3D.pi * self._radius
    
    def __str__(self):
        return "Radius: "+str(self._radius)

class Sphere(Shape3D):
    def __init__(self,name,rad):
        super().__init__(name,rad)
        print(f"Shape name: {self._name}, Area Formula: 4 * pi * r * r")
    def calc_surface_area(self):
        return 4*Shape3D.pi*self._radius**2
    def __str__(self):
        return f"Radius:{self._radius} Height: No Need\nArea: {self.calc_surface_area()}"
class Cylinder(Shape3D):
    def __init__(self,name,rad,rad1):
        self._height1=rad1
        super().__init__(name,rad)
        print(f"Shape name: {self._name}, Area Formula: 2 * pi * r * (r + h)")
    def calc_surface_area(self):
        return 2*Shape3D.pi*self._radius*self._height1+2*Shape3D.pi*self._radius**2
    def __str__(self):
        return f"Radius:{self._radius} Height: {self._height1}\nArea: {self.calc_surface_area()}"
        
sph = Sphere('Sphere', 5)
print('----------------------------------')
sph.calc_surface_area()
print(sph)
print('==================================')
cyl = Cylinder('Cylinder', 5, 10)
print('----------------------------------')
cyl.calc_surface_area()
print(cyl)
# Out:
# Shape name: Sphere, Area Formula: 4 * pi * r * r
# ----------------------------------
# Radius:5 Height: No Need
# Area: 314.159
# ...
# Shape name: Cylinder, Area Formula: 2 * pi * r * (r + h)
# ----------------------------------
# Radius:5 Height: 10
# Area: 471.2385

# %%
class PokemonBasic:

    def __init__(self, name = 'Default', hp = 0, weakness = 'None', type1 = 'Unknown'):
        self.name = name
        self.hit_point = hp
        self.weakness = weakness
        self.type = type1

    def get_type(self):
        return 'Main type: ' + self.type

    def get_move(self):
        return 'Basic move: ' + 'Quick Attack'

    def __str__(self):
        return "Name: " + self.name + ", HP: " + str(self.hit_point) + ", Weakness: " + self.weakness

class PokemonExtra(PokemonBasic):
    def __init__(self, name1,hp1,wek1,type1,type2=None,otherMove=None):
        super().__init__(name1,hp1,wek1,type1)
        self.type2=type2
        self.otherMoves=[]
        if otherMove:
            for i in otherMove:
                self.otherMoves.append(i)

    def get_type(self):
        if self.type2:
            return f"Main type: {self.type} Second type: {self.type2}"
        else:
            return 'Main type: ' + self.type

    def get_move(self):
        if len(self.otherMoves)!=0:
            for x in self.otherMoves:
                return "Basic move: Quick Attack" + "Other moves:"+ ','.join(self.otherMoves)

    def __str__(self):
        return "Name: " + self.name + ", HP: " + str(self.hit_point) + ", Weakness: " + self.weakness
    
    
print('\n------------Basic Info:--------------')
pk = PokemonBasic()
print(pk)
print(pk.get_type())
print(pk.get_move())

print('\n------------Pokemon 1 Info:-------------')
charmander = PokemonExtra('Charmander', 39, 'Water', 'Fire')
print(charmander)
print(charmander.get_type())
print(charmander.get_move())

print('\n------------Pokemon 2 Info:-------------')
charizard = PokemonExtra('Charizard', 78, 'Water', 'Fire', 'Flying', ('Fire Spin', 'Fire Blaze'))
print(charizard)
print(charizard.get_type())
print(charizard.get_move())
# Out:
# ------------Basic Info:--------------
# Name: Default, HP: 0, Weakness: None
# Main type: Unknown
# Basic move: Quick Attack
#
# ------------Pokemon 1 Info:-------------
# Name: Charmander, HP: 39, Weakness: Water
# Main type: Fire
# None
#
# ------------Pokemon 2 Info:-------------
# Name: Charizard, HP: 78, Weakness: Water
# Main type: Fire Second type: Flying
# Basic move: Quick AttackOther moves:Fire Spin,Fire Blaze

# %%
class Team:
    def __init__(self, name):
        self.name = "default"
        self.total_player = 5
    def info(self):
        print("We love sports")
        
class FootBallTeam(Team):
    def __init__(self,name):
        self.name = name
        self.total_player=11
    def info(self):
        print(f"Our name is {self.name}")
        print("We love to play football")
        print("We love sports")
        
class CricketTeam(Team):
    def __init__(self,name):
        self.name = name
        self.total_player=11
    def info(self):
        print(f"Our name is {self.name}")
        print("We love to play Cricket")
        print("We love sports")

class Team_test:
    def check(self, tm):
        print("=========================")
        print("Total Player: ", tm.total_player)
        tm.info()

f = FootBallTeam("Brazil")
c = CricketTeam("Bangladesh")
test = Team_test()
test.check(f)
test.check(c)
# Out:
# ...
# Total Player:  11
# Our name is Brazil
# We love to play football
# We love sports
# ...
# Total Player:  11
# Our name is Bangladesh
# We love to play Cricket
# We love sports

# %%
#1
class BankAccount:
    def __init__(self,name,typ):
        self.user_name=name
        self.account_type=typ
        self.balance=1.0
    def updateBalance(self,num):
        self.balance+=num
        return self.balance

account1 = BankAccount("Bilbo", "Savings")
print("=====================================")
print(f"User Name: {account1.user_name}")
print(f"Balance: {account1.balance}")
print(f"Account Type:", account1.account_type)
print("=====================================")
account2 = BankAccount("Frodo", "Business")
print(f"User Name: {account2.user_name}")
print(f"Balance: {account2.balance}")
print(f"Account Type: {account2.account_type}")
print("=====================================")
print(f"New account balance of {account1.user_name} is {account1.updateBalance(14.75)}")
print(f"New account balance of {account2.user_name} is {account2.updateBalance(699.5)}")
# Out:
# ...
# User Name: Bilbo
# Balance: 1.0
# Account Type: Savings
# ...
# User Name: Frodo
# Balance: 1.0
# Account Type: Business
# ...
# New account balance of Bilbo is 15.75
# New account balance of Frodo is 700.5

# %%
#2
class MangoTree:
    def __init__(self,ver,height=1,num=0):
        self.variety=ver
        self.height=height
        self.number_of_mangoes=num
    def newHeight(self):
        self.height+=5*3
        return self.height
    def newAmount(self):
        if self.variety=="Gopalbhog":
            self.number_of_mangoes+=self.height*10
            return self.number_of_mangoes
        else:
            self.number_of_mangoes+=self.height*15
            return self.number_of_mangoes

mangoTree1= MangoTree("Gopalbhog")
# Display the details of the mango tree
print("=====================================")
print("Mango Tree Details:")
print(f"Variety: {mangoTree1.variety}")
print(f"Height: {mangoTree1.height} meter(s)")
print(f"Number of mangoes on the tree: {mangoTree1.number_of_mangoes}")
print("=====================================")
mangoTree2= MangoTree("Amrapali")
# Display the details of the mango tree
print("Mango Tree Details:")
print(f"Variety: {mangoTree2.variety}")
print(f"Height: {mangoTree2.height} meter(s)")
print(f"Number of mangoes on the tree: {mangoTree2.number_of_mangoes}")
print("=====================================")
mangoTree3= MangoTree("Gopalbhog")
print("Updated details after 5 years:")
print("=====================================")
print(f"Variety: {mangoTree3.variety}")
print(f"Height: {mangoTree3.newHeight()} meter(s)")
print(f"Number of mangoes on the tree: {mangoTree3.newAmount()}")
print("=====================================")
mangoTree4= MangoTree("Amrapali")
print(f"Variety: {mangoTree4.variety}")
print(f"Height: {mangoTree4.newHeight()} meter(s)")
print(f"Number of mangoes on the tree: {mangoTree4.newAmount()}")
print("=====================================")
# Out:
# ...
# Mango Tree Details:
# Variety: Gopalbhog
# Height: 1 meter(s)
# Number of mangoes on the tree: 0
# ...
# Mango Tree Details:
# Variety: Amrapali
# Height: 1 meter(s)
# Number of mangoes on the tree: 0
# ...
# Updated details after 5 years:
# ...
# Variety: Gopalbhog
# Height: 16 meter(s)
# Number of mangoes on the tree: 160
# ...
# Variety: Amrapali
# Height: 16 meter(s)
# Number of mangoes on the tree: 240
# ...

# %%
#4
class Student:
    def __init__(self,name,cgpa,courses_taken):
        self.name=name
        self.cgpa=cgpa
        if cgpa>=2.00:
            self.student_status="Regular"
        else:
            self.student_status="Probation"
        self.courses_taken=courses_taken
        if courses_taken>2 and self.student_status=="Probation":
            self.advising_status="Denied"
            print(f"Sorry, {self.name}, you are on probation and cannot take more than 2 courses.")
        elif (courses_taken>5 or courses_taken<3) and self.student_status=="Regular":
            self.advising_status="Denied"
            print(f"Hello {self.name}, You are a regular student and have to take between 3 to 5 courses.")
        elif 5>=courses_taken>=3 and self.student_status=="Regular":
            self.advising_status="Approved"
            print(f"All the best, {self.name}, for the upcoming semester")
        elif 0<courses_taken<=2 and self.student_status=="Probation":
            self.advising_status="Approved"
            print(f"Study hard this time, {self.name}")

s1 = Student("Clark", 3.45, 4)
print(f"Name: {s1.name}\nCGPA: {s1.cgpa}\nCourses Taken: {s1.courses_taken}")
print(f"Student Status: {s1.student_status}\nAdvising Status: {s1.advising_status}")
print("--------------------------------------------------------------------------------")
s2 = Student("Barry", 1.93, 2)
print(f"Name: {s2.name}")
print(f"Student Status: {s2.student_status}\nAdvising Status: {s2.advising_status}")
print("--------------------------------------------------------------------------------")
s3 = Student("Diana", 2.91, 2)
print(f"Advising Status: {s3.advising_status}\nCourses Taken: {s3.courses_taken}")
print("--------------------------------------------------------------------------------")
s4 = Student("Bruce", 1.52, 5)
print(f"Advising Status: {s4.advising_status}\nCourses Taken: {s4.courses_taken}")
# Out:
# All the best, Clark, for the upcoming semester
# Name: Clark
# CGPA: 3.45
# Courses Taken: 4
# Student Status: Regular
# Advising Status: Approved
# --------------------------------------------------------------------------------
# Study hard this time, Barry
# Name: Barry
# Student Status: Probation
# Advising Status: Approved
# --------------------------------------------------------------------------------
# Hello Diana, You are a regular student and have to take between 3 to 5 courses.
# Advising Status: Denied
# Courses Taken: 2
# --------------------------------------------------------------------------------
# Sorry, Bruce, you are on probation and cannot take more than 2 courses.
# Advising Status: Denied
# Courses Taken: 5

# %%
#5
class Book:
    def __init__(self,name,author,year):
        self.name=name
        self.author=author
        self.year_of_publication=year
        if 100<=(2023-year)<200:
            self.status="This book is Accepted. The book is stored on floor: 0."
        elif 400>(2023-year)>=200:
            self.status="This book is Accepted. The book is stored on floor: 1."
        elif (2023-year)>=400:
            self.status="This book is Accepted. The book is stored on floor: 2."
        else:
            self.status="This book is Rejected. The book is not antique enough."

book1= Book('The Act', 'Ferguson', 1924)
print(f"{book1.author} wrote the book '{book1.name}'.")
print(f"This book was published in {book1.year_of_publication}.")
print(f"This book is {book1.status}")
print("-------------------------------------")
book2= Book('Flame', 'Nolan', 1932)
print(f"{book2.author} wrote the book '{book2.name}'.")
print(f"This book was published in {book2.year_of_publication}.")
print(f"This book is {book2.status}")
print("-------------------------------------")
book3= Book('Norms', 'Alfred', 1832)
print(f"{book3.author} wrote the book '{book3.name}'.")
print(f"This book was published in {book3.year_of_publication}.")
print(f"This book is {book3.status}")
print("-------------------------------------")
book4= Book('Apex', 'Samson', 1923)
print(f"{book4.author} wrote the book '{book4.name}'.")
print(f"This book was published in {book4.year_of_publication}.")
print(f"This book is {book4.status}")
print("-------------------------------------")
book5= Book('Habitat', 'Eden', 1723)
print(f"{book5.author} wrote the book '{book5.name}'.")
print(f"This book was published in {book5.year_of_publication}.")
print(f"This book is {book5.status}")
print("-------------------------------------")
book6= Book('Apocalypto', 'Menez', 1603)
print(f"{book6.author} wrote the book '{book6.name}'.")
print(f"This book was published in {book6.year_of_publication}.")
print(f"This book is {book6.status}")
# Out:
# Ferguson wrote the book 'The Act'.
# This book was published in 1924.
# This book is This book is Rejected. The book is not antique enough.
# -------------------------------------
# Nolan wrote the book 'Flame'.
# This book was published in 1932.
# This book is This book is Rejected. The book is not antique enough.
# -------------------------------------
# Alfred wrote the book 'Norms'.
# This book was published in 1832.
# This book is This book is Accepted. The book is stored on floor: 0.
# -------------------------------------
# Samson wrote the book 'Apex'.
# This book was published in 1923.
# This book is This book is Accepted. The book is stored on floor: 0.
# -------------------------------------
# Eden wrote the book 'Habitat'.
# This book was published in 1723.
# This book is This book is Accepted. The book is stored on floor: 1.
# -------------------------------------
# Menez wrote the book 'Apocalypto'.
# This book was published in 1603.
# ...

# %%
inp=input("Enter here: ")
count=0
final=""
for i in range (len(inp)):
    if i==0:
        final+=chr(ord(inp[i])-32)
    elif i>1 and (inp[i-2]=="." or inp[i-2]=="?" or inp[i-2]=="!"):
        final+=chr(ord(inp[i])-32)
    elif inp[i]=="i" and inp[i+1]==" " and inp[i-1]==" ":
        final+=chr(ord(inp[i])-32)
    else:
        final+=inp[i]
print("-----------------------------------------------------------------------------------------------------")
print()
print("After Change:")
print(final)
# Out:
# Enter here: my favourite animal is dog. a dog has very sharp teeth which helps them to tear the flesh. do you know my pet dog name? i love my pet very much.
# -----------------------------------------------------------------------------------------------------
#
# After Change:
# My favourite animal is dog. A dog has very sharp teeth which helps them to tear the flesh. Do you know my pet dog name? I love my pet very much.

# %%
class CellPackage:
    def __init__(self,price,data,talktime,sms,cashback,validity):
        self.price=price
        self.talktime=talktime
        self.sms=sms
        self.cashback=0
        cashback=cashback.replace("%","")
        if len(cashback)==1:
            self.cashback+=int(self.price*float("0.0"+cashback))
        else:
            self.cashback+=int(self.price*float("0."+cashback))
        self.validity=validity
        self.data=0
        self.data1=int(data.replace(" GB",""))
        for i in range (self.data1):
            self.data+=1024
    def printDetail(self):
        print(f"Data = {self.data}")
        print(f"Talktime = {self.talktime} Min")
        print(f"SMS = {self.sms}")
        print(f"Validity = {self.validity}")
        print(f"--> price = {self.price}")
        if self.cashback!=0:
            print(f"Buy now to get {self.cashback} tk cashback.")
        
        
        

pkg = CellPackage(150, '6 GB', 99, 20, '7%', 7)
print('============= Package 1 =============')
pkg.printDetail()


pkg2 = CellPackage(700, '35 GB', 700, 0, '10%', 30)
print('============= Package 2 =============')
pkg2.printDetail()


pkg4 = CellPackage(120, '0 GB', 190, 0, '0%', 10)
print('============= Package 3 =============')
pkg4.printDetail()
# Out:
# ============= Package 1 =============
# Data = 6144
# Talktime = 99 Min
# SMS = 20
# Validity = 7
# --> price = 150
# Buy now to get 10 tk cashback.
# ============= Package 2 =============
# Data = 35840
# Talktime = 700 Min
# SMS = 0
# Validity = 30
# --> price = 700
# Buy now to get 70 tk cashback.
# ============= Package 3 =============
# Data = 0
# Talktime = 190 Min
# SMS = 0
# Validity = 10
# --> price = 120

# %%
class Pokemon:
    def __init__(self,name1,name2,power1,power2,combo):
        self.pokemon1_name=name1
        self.pokemon1_power=power1
        self.pokemon2_name=name2
        self.pokemon2_power=power2
        self.damage_rate=combo



team_pika = Pokemon('pikachu', 'charmander', 90, 60, 10)
print('=======Team 1=======')
print('Pokemon 1:',team_pika.pokemon1_name, team_pika.pokemon1_power)
print('Pokemon 2:',team_pika.pokemon2_name, team_pika.pokemon2_power)
pika_combined_power = (team_pika.pokemon1_power + team_pika.pokemon2_power) * team_pika.damage_rate
print('Combined Power:', pika_combined_power)
team_bulb = Pokemon('bulbasaur', 'squirtle', 80, 70, 9)
print('=======Team 2=======')
print('Pokemon 1:',team_bulb.pokemon1_name, team_bulb.pokemon1_power)
print('Pokemon 2:',team_bulb.pokemon2_name, team_bulb.pokemon2_power)
bulb_combined_power = (team_bulb.pokemon1_power + team_bulb.pokemon2_power) * team_bulb.damage_rate
print('Combined Power:', bulb_combined_power)
# Out:
# =======Team 1=======
# Pokemon 1: pikachu 90
# Pokemon 2: charmander 60
# Combined Power: 1500
# =======Team 2=======
# Pokemon 1: bulbasaur 80
# Pokemon 2: squirtle 70
# Combined Power: 1350

# %%
class box:
    def __init__(self,lst):
        print("Creating a Box")
        count=0
        for i in lst:
            if count==0:
                self.height=i
                count+=1
            elif count==1:
                self.width=i
                count+=1
            else:
                self.breadth=i


print("Box 1")
b1 = box([10,10,10])
print("=========================")
print("Height:", b1.height)
print("Width:", b1.width)
print("Breadth:", b1.breadth)
volume = b1.height * b1.width * b1.breadth
print(f"Volume of the box is {volume} cubic units.")
print("-------------------------")
print("Box 2")
b2 = box((30,10,10))
print("=========================")
print("Height:", b2.height)
print("Width:", b2.width)
print("Breadth:", b2.breadth)
volume = b2.height * b2.width * b2.breadth
print(f"Volume of the box is {volume} cubic units.")
b2.height = 300
print("Updating Box 2!")
print("Height:", b2.height)
print("Width:", b2.width)
print("Breadth:", b2.breadth)
volume = b2.height * b2.width * b2.breadth
print(f"Volume of the box is {volume} cubic units.")
print("-------------------------")
print("Box 3")
b3 = b2
print("Height:", b3.height)
print("Width:", b3.width)
print("Breadth:", b3.breadth)
volume = b3.height * b3.width * b3.breadth
print(f"Volume of the box is {volume} cubic units.")
# Out:
# Box 1
# Creating a Box
# ...
# Height: 10
# Width: 10
# Breadth: 10
# Volume of the box is 1000 cubic units.
# -------------------------
# Box 2
# Creating a Box
# ...
# Height: 30
# Width: 10
# Breadth: 10
# Volume of the box is 3000 cubic units.
# Updating Box 2!
# Height: 300
# Width: 10
# Breadth: 10
# Volume of the box is 30000 cubic units.
# -------------------------
# Box 3
# Height: 300
# Width: 10
# Breadth: 10
# Volume of the box is 30000 cubic units.

# %%
import numpy
class Vector3D:
    def __init__(self, x, y, z):
        self.x = x 
        self.y = y
        self.z = z
        print(f'Vector <{self.x}, {self.y}, {self.z}> has been created.')
        
vec1=Vector3D(2,-3,1)
vec2=Vector3D(-1,4,0)
Magnitude1= numpy.sqrt(vec1.x**2+vec1.y**2+vec1.z**2)
Magnitude2= numpy.sqrt(vec2.x**2+vec2.y**2+vec2.z**2)
print("Magnitude of the first vector =",Magnitude1)
print("Magnitude of the second vector =",Magnitude2)
dot=(vec1.x*vec2.x)+(vec1.y*vec2.y)+(vec1.z*vec2.z)
print("Dot product of the two vectors =",dot)
vec3=Vector3D(-4,-1,5)
print("Cross product of the two vectors = <",vec3.x, ",",vec3.y,",",vec3.z,">")
# Out:
# Vector <2, -3, 1> has been created.
# Vector <-1, 4, 0> has been created.
# Magnitude of the first vector = 3.7416573867739413
# Magnitude of the second vector = 4.123105625617661
# Dot product of the two vectors = -14
# Vector <-4, -1, 5> has been created.
# Cross product of the two vectors = < -4 , -1 , 5 >
